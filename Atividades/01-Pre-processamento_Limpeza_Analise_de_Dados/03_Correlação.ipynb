# %% [markdown]
# <a href="https://colab.research.google.com/github/Francisco-Italo/ml2023-Italo-Moraes/blob/master/Atividades/01-Pre-processamento_Limpeza_Analise_de_Dados/03_Correla%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3 - Correlação
# **Direto ao ponto**: correlação é o coeficiente de interdependência entre duas ou mais variáveis.
#
# Em muitos casos, quando analisamos algumas variáveis, essa interdependência é muito clara. Exemplo:
# - Massa corporal e altura,
# - Consumo de combustível e distância percorrida,
# - Número de anúncios e produtos vendidos,
# - Tempo de estudo e desempenho na avaliação.
#
# Entretanto, algumas vezes essa correlação pode não ser muito clara.
#
# Lembrete:
# **Correlação é diferente de causalidade!**

# %% [markdown]
# ## Correlações positivas

# %%
import numpy as np

# Semente para geração de números aleatorios
np.random.seed(1)

# 1000 random integers between 0 and 50
x = np.random.randint(0, 50, 1000)

# Positive Correlation with some noise
y = x + np.random.normal(0, 10, 1000)

# Return Pearson product-moment correlation coefficients :D
np.corrcoef(x, y)
# Out:
# array([[1.        , 0.81543901],
#        [0.81543901, 1.        ]])

# %%
# import matplotlib
import matplotlib.pyplot as plt

# Imprime todos os pontos após o Pearson product-moment correlation
plt.scatter(x, y)

# %% [markdown]
# ## Correlações negativas

# %%
# 1000 random integers between 0 and 50
x = np.random.randint(0, 50, 1000)

# Negative Correlation with some noise
y = 100 - x + np.random.normal(0, 5, 1000)

# Pearson product-moment correlation
np.corrcoef(x, y)
# Out:
# array([[ 1.        , -0.94957116],
#        [-0.94957116,  1.        ]])

# %%
plt.scatter(x, y)

# %% [markdown]
# ## Correlação fraca ou sem correlação

# %% [markdown]
# Aplicação do Pearson product-moment correlation com dois numerais aleatorizados de forma independente um do outro

# %%
x = np.random.randint(0, 50, 1000)
y = np.random.randint(0, 50, 1000)

np.corrcoef(x, y)
# Out:
# array([[ 1.        , -0.00554681],
#        [-0.00554681,  1.        ]])

# %%
plt.scatter(x, y)
